# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
student_data=pd.read_csv('CleanStudent.csv')
student_data.head()
# Out:
#    gender race_ethnicity parental_level_of_education  lunch  \
# 0       0        group B           bachelor's degree      1
# 1       0        group C                some college      1
# 2       0        group B             master's degree      1
# 3       1        group A          associate's degree      0
# 4       1        group C                some college      1
#
#    test_preparation_course  math_score  reading_score  writing_score  \
# 0                        0          72             72             74
# 1                        1          69             90             88
# 2                        0          90             95             93
# 3                        0          47             57             44
# 4                        0          76             78             75
#
#    total_score  average_score
# 0          218      72.666667
# 1          247      82.333333
# 2          278      92.666667
# 3          148      49.333333
# 4          229      76.333333

# %%
student_data=pd.read_csv('CleanStudent.csv', sep=';')
student_data.head()
# Out:
#   gender,race_ethnicity,parental_level_of_education,lunch,test_preparation_course,math_score,reading_score,writing_score,total_score,average_score
# 0  0,group B,bachelor's degree,1,0,72,72,74,218,7...
# 1  0,group C,some college,1,1,69,90,88,247,82.333...
# 2  0,group B,master's degree,1,0,90,95,93,278,92....
# 3  1,group A,associate's degree,0,0,47,57,44,148,...
# 4  1,group C,some college,1,0,76,78,75,229,76.333...

# %%
student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column                                                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                                                            --------------  -----
#  0   gender,race_ethnicity,parental_level_of_education,lunch,test_preparation_course,math_score,reading_score,writing_score,total_score,average_score  1000 non-null   object
# dtypes: object(1)
# memory usage: 7.9+ KB

# %%
student_data.isnull().sum()
# Out:
# gender,race_ethnicity,parental_level_of_education,lunch,test_preparation_course,math_score,reading_score,writing_score,total_score,average_score    0
# dtype: int64

# %%
student_data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
student_data = pd.read_csv('CleanStudent.csv')

student_data.head()


plt.figure(figsize=(8, 6))
plt.hist(student_data['gender'], bins=2)
plt.xlabel('Gender')
plt.ylabel('Count')  
plt.title('Distribution of Gender')
plt.grid(True)
plt.show()

# %%
student_data.describe()
# Out:
#             gender        lunch  test_preparation_course  math_score  \
# count  1000.000000  1000.000000              1000.000000  1000.00000
# mean      0.482000     0.645000                 0.358000    66.08900
# std       0.499926     0.478753                 0.479652    15.16308
# min       0.000000     0.000000                 0.000000     0.00000
# 25%       0.000000     0.000000                 0.000000    57.00000
# 50%       0.000000     1.000000                 0.000000    66.00000
# 75%       1.000000     1.000000                 1.000000    77.00000
# max       1.000000     1.000000                 1.000000   100.00000
#
#        reading_score  writing_score  total_score  average_score
# count    1000.000000    1000.000000  1000.000000    1000.000000
# mean       69.169000      68.054000   203.312000      67.770667
# std        14.600192      15.195657    42.771978      14.257326
# min        17.000000      10.000000    27.000000       9.000000
# ...

# %%
student_data['math_score'].median()
# Out:
# np.float64(66.0)

# %%
student_data['reading_score'].mode()
# Out:
# 0    72
# Name: reading_score, dtype: int64

# %%
student_data['math_score'].var()
# Out:
# np.float64(229.91899799799796)

# %%
plt.boxplot(student_data['math_score'])
plt.grid(True)
plt.show()

# %%
plt.boxplot(student_data['total_score'])
plt.grid(True)
plt.show()

# %%
# ... existing code ...

# Correct boxplot for multiple columns
plt.figure(figsize=(10, 6))
plt.boxplot([
    student_data['reading_score'],
    student_data['math_score'],
    student_data['writing_score'],
    student_data['total_score']
])
plt.xticks([1, 2, 3, 4], ['Reading', 'Math', 'Writing', 'Total'])
plt.ylabel('Scores')
plt.title('Distribution of Student Scores')
plt.grid(True)
plt.show()

# If you need to install packages, use this correct syntax:
# !pip install pandas numpy matplotlib pandas-datareader

# %%
# Calculate CV only for numerical columns
numerical_columns = ['math_score', 'reading_score', 'writing_score', 'total_score', 'average_score']
CV = student_data[numerical_columns].std() / student_data[numerical_columns].mean()
CV
# Out:
# math_score       0.229434
# reading_score    0.211080
# writing_score    0.223288
# total_score      0.210376
# average_score    0.210376
# dtype: float64

# %%
# 1. Load the data correctly (only need to do this once)
student_data = pd.read_csv('CleanStudent.csv')

# 2. For covariance calculation, use only numerical columns
numerical_columns = ['math_score', 'reading_score', 'writing_score', 'total_score', 'average_score']
covariance_matrix = student_data[numerical_columns].cov()

# 3. If you need to install packages, use this command in the terminal or notebook:
# !pip install pandas numpy matplotlib pandas-datareader

# %%
np.cov(student_data[numerical_columns].T)
# Out:
# array([[ 229.918998  ,  180.99895796,  184.93913313,  595.85708909,
#          198.6190297 ],
#        [ 180.99895796,  213.1656046 ,  211.78666066,  605.95122322,
#          201.98374107],
#        [ 184.93913313,  211.78666066,  230.90799199,  627.63378579,
#          209.21126193],
#        [ 595.85708909,  605.95122322,  627.63378579, 1829.4420981 ,
#          609.8140327 ],
#        [ 198.6190297 ,  201.98374107,  209.21126193,  609.8140327 ,
#          203.27134423]])

# %%
pip install pandas numpy matplotlib pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print(student_data['math_score'].corr(student_data['reading_score']))
print(student_data['math_score'].corr(student_data['writing_score']))
print(student_data['math_score'].corr(student_data['total_score']))
print(student_data['math_score'].corr(student_data['average_score']))
# Out:
# 0.817579663672055
# 0.8026420459498088
# 0.9187457588383459
# 0.9187457588383452

# %%
student_data.corr()

# %%
plt.plot(student_data['math_score'],student_data['reading_score'],'o')
plt.grid(True)
plt.show(	)

# %%
numerical_columns = ['math_score', 'reading_score', 'writing_score', 'total_score', 'average_score']
sns.pairplot(student_data[numerical_columns])
plt.show()

# %%
# !pip install pandas numpy matplotlib pandas-datareader
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 1.3 MB/s eta 0:00:03
#    -------- ------------------------------- 0.8/3.8 MB 1.4 MB/s eta 0:00:03
#    ------------- -------------------------- 1.3/3.8 MB 1.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.6/3.8 MB 1.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 2.1/3.8 MB 1.7 MB/s eta 0:00:02
#    ------------------------ --------------- 2.4/3.8 MB 1.6 MB/s eta 0:00:01
#    ------------------------------ --------- 2.9/3.8 MB 1.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.8 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 1.7 MB/s eta 0:00:00
# ...

# %%
pip inslall pandas , numpy , matplotlib , pandas_datareader
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "inslall" - maybe you meant "install"
